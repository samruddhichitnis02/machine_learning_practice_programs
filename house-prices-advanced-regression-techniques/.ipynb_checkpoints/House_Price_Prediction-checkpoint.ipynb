# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
len(data['Id'].unique())
# Out:
# 1460

# %%
data.drop(['Id'], axis = 1, inplace = True)

# %%
data.shape
# Out:
# (1460, 80)

# %%
fig, ax = plt.subplots(figsize = (10,8))
sb.heatmap(data.isna(),
          cbar = None,
          yticklabels = False,
          cmap = 'Blues')
plt.show()

# %% [markdown]
# # Droping the columns who has data  less than 50%

# %%
data = data[[column for column in data if data[column].count() / len(data) >= 0.5]]

# %%
data.shape
# Out:
# (1460, 76)

# %%
fig, ax = plt.subplots(figsize = (10,8))
sb.heatmap(data.isna(),
          cbar = None,
          yticklabels = False,
          cmap = 'Blues')
plt.show()

# %%
for i in data.columns:
    print(i)
# Out:
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition
# SalePrice

# %% [markdown]
# # Getting the columns having Missing values along with their missing values

# %%
Null_Values = [ ]
types = [ ]
for i in data.columns:
    if (data[i].isnull().sum() > 0):
        Null_Values.append(data[i].isnull().sum())
        types.append(data[i].dtype)

# %%
pd.DataFrame({'Column': data.columns[data.isnull().any()],
              'Null_Values': Null_Values,
             'Datatype': types})
# Out:
#           Column  Null_Values Datatype
# 0    LotFrontage          259  float64
# 1     MasVnrType            8   object
# 2     MasVnrArea            8  float64
# 3       BsmtQual           37   object
# 4       BsmtCond           37   object
# 5   BsmtExposure           38   object
# 6   BsmtFinType1           37   object
# 7   BsmtFinType2           38   object
# 8     Electrical            1   object
# 9    FireplaceQu          690   object
# 10    GarageType           81   object
# 11   GarageYrBlt           81  float64
# 12  GarageFinish           81   object
# 13    GarageQual           81   object
# 14    GarageCond           81   object

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Checking if their are outliers to handle missing values

# %%
plt.figure(figsize=(20,8))
sb.boxplot(x = "LotFrontage", y = "SalePrice", data = data[data['LotFrontage'] < 90])
plt.show()

# %%
plt.figure(figsize=(20,8))
sb.boxplot(x = "LotFrontage", y = "SalePrice", data = data[data['LotFrontage'] >= 90])
plt.show()

# %%
data['LotFrontage'] = data['LotFrontage'].fillna(data['LotFrontage'].mean())

# %%
plt.figure(figsize=(20,8))
sb.boxplot(x = "MasVnrArea", y = "SalePrice", data = data)
plt.show()

# %%
data['MasVnrArea'] = data['MasVnrArea'].fillna(data['MasVnrArea'].mean())

# %%
data['BsmtQual'] = data['BsmtQual'].fillna(data['BsmtQual'].mode()[0])
data['BsmtCond'] = data['BsmtCond'].fillna(data['BsmtCond'].mode()[0])
data['BsmtExposure'] = data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0])

data['MasVnrType'] = data['MasVnrType'].fillna(data['MasVnrType'].mode()[0])
data['BsmtFinType1'] = data['BsmtFinType1'].fillna(data['BsmtFinType1'].mode()[0])
data['BsmtFinType2'] = data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0])

# %%
data['FireplaceQu'] = data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0])
data['GarageType'] = data['GarageType'].fillna(data['GarageType'].mode()[0])

data['GarageFinish'] = data['GarageFinish'].fillna(data['GarageFinish'].mode()[0])
data['GarageQual'] = data['GarageQual'].fillna(data['GarageQual'].mode()[0])
data['GarageCond'] = data['GarageCond'].fillna(data['GarageCond'].mode()[0])

# %%
plt.figure(figsize=(20,8))
sb.boxplot(x = "GarageYrBlt", y = "SalePrice", data = data[data['GarageYrBlt'] < 1975])
plt.show()

# %%
plt.figure(figsize=(20,8))
sb.boxplot(x = "GarageYrBlt", y = "SalePrice", data = data[data['GarageYrBlt'] >= 1975])
plt.show()

# %%
data['GarageYrBlt'] = data['GarageYrBlt'].fillna(data['GarageYrBlt'].mean())

# %%
fig, ax = plt.subplots(figsize = (10,8))
sb.heatmap(data.isna(),
          cbar = None,
          yticklabels = False,
          cmap = 'viridis')
plt.show()

# %%
sb.distplot(data['SalePrice'])
plt.show()

# %%
data.hist(figsize=(16, 20), bins=50, xlabelsize=10, ylabelsize=8)
plt.show()

# %%
objects = [ ]
for i in data.columns:
    if data[i].dtypes == object:
        objects.append(i)
